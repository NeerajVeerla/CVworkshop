# %% [markdown]
# <a href="https://colab.research.google.com/github/NeerajVeerla/CVworkshop/blob/master/Day1/opencvBasic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


img = cv2.imread("imagePro1.jpg",cv2.IMREAD_COLOR)
img=img/3

# %%
print(img)
# Out:
# [[[ 60  67  70]
#   [ 71  79  79]
#   [ 84  89  90]
#   ...
#   [ 66  43  27]
#   [ 66  43  27]
#   [ 66  44  26]]
#
#  [[  9  17  34]
#   [ 15  24  38]
#   [ 22  30  43]
#   ...
#   [ 61  42  34]
#   [ 61  43  32]
#   [ 60  42  31]]
#
#  [[ 21  33  75]
#   [ 19  31  73]
#   [ 16  27  65]
#   ...
#   [ 54  44  50]
#   [ 53  42  45]
#   [ 50  39  41]]
#
#  ...
#
#  [[152 155 159]
#   [158 162 167]
#   [163 165 175]
#   ...
#   [133  49   7]
#   [130  48   6]
#   [129  47   5]]
#
#  [[162 162 168]
#   [160 163 168]
#   [167 168 178]
#   ...
#   [132  48   6]
#   [129  47   5]
#   [130  48   6]]
#
#  [[164 164 170]
#   [159 158 167]
#   [165 166 176]
#   ...
#   [131  47   5]
#   [128  46   4]
#   [130  48   6]]]

# %%
img.shape
# Out:
# (150, 150, 3)

# %%
plt.imshow(img)

# %%
img[0,0,0]
# Out:
# 60

# %%
img1=img[0:150,0:150,2]
plt.imshow(img1,cmap='gray')

# %%
img2=img[0:75,0:75,0]
plt.imshow(img2)

# %%
img2=img[0:75,0:75,2]
plt.imshow(img2)

# %%
img3=np.swapaxes(img,0, 1)
plt.imshow(img3)

# %%
dst = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(dst)
